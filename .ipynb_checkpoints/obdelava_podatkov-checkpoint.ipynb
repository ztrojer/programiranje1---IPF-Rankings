# %% [markdown]
# # IPF RANKINGS

# %%
import pandas as pd
pd.options.display.max_rows = 20

# %% [markdown]
# ## UREJANJE PODATKOV
# Preberemo csv, združimo v tabeli *moski* in *zenske*.

# %%
MM1 = pd.read_csv("uvoz_podatkov/6th_world_classic_MM1.csv", index_col = "ID_tekmovalca")
MM2 = pd.read_csv("uvoz_podatkov/6th_world_classic_MM2.csv", index_col = "ID_tekmovalca")
MM3 = pd.read_csv("uvoz_podatkov/6th_world_classic_MM3.csv", index_col = "ID_tekmovalca")
MM4 = pd.read_csv("uvoz_podatkov/6th_world_classic_MM4.csv", index_col = "ID_tekmovalca")

WM1 = pd.read_csv("uvoz_podatkov/6th_world_classic_WM1.csv", index_col = "ID_tekmovalca")
WM2 = pd.read_csv("uvoz_podatkov/6th_world_classic_WM2.csv", index_col = "ID_tekmovalca")
WM3 = pd.read_csv("uvoz_podatkov/6th_world_classic_WM3.csv", index_col = "ID_tekmovalca")
WM4 = pd.read_csv("uvoz_podatkov/6th_world_classic_WM4.csv", index_col = "ID_tekmovalca")

wMM1 = pd.read_csv("uvoz_podatkov/world_masters_MM1.csv", index_col = "ID_tekmovalca")
wMM2 = pd.read_csv("uvoz_podatkov/world_masters_MM2.csv", index_col = "ID_tekmovalca")
wMM3 = pd.read_csv("uvoz_podatkov/world_masters_MM3.csv", index_col = "ID_tekmovalca")
wMM4 = pd.read_csv("uvoz_podatkov/world_masters_MM4.csv", index_col = "ID_tekmovalca")

wWM1 = pd.read_csv("uvoz_podatkov/world_masters_WM1.csv", index_col = "ID_tekmovalca")
wWM2 = pd.read_csv("uvoz_podatkov/world_masters_WM2.csv", index_col = "ID_tekmovalca")
wWM3 = pd.read_csv("uvoz_podatkov/world_masters_WM3.csv", index_col = "ID_tekmovalca")
wWM4 = pd.read_csv("uvoz_podatkov/world_masters_WM4.csv", index_col = "ID_tekmovalca")

moski = pd.concat([MM1, MM2, MM3, MM4, wMM1, wMM2, wMM3, wMM4])
zenske = pd.concat([WM1, WM2, WM3, WM4, wWM1, wWM2, wWM3, wWM4])

# %% [markdown]
# V tabeli *moski* in *zenske* dodamo nov stolpec *kategorija*, v katerem so kategorije v katero tekmovalec spada. Tabeli nato združimo v tabelo *tekmovalci*.

# %%
def kategorija_m(s):
    if (s['teza'] <= 59):
        return 'moški 59 kg'
    elif (s['teza'] <= 66):
        return 'moški 66 kg'
    elif (s['teza'] <= 74):
        return 'moški 74 kg'
    elif (s['teza'] <= 83):
        return 'moški 83 kg'
    elif (s['teza'] <= 93):
        return 'moški 93 kg'
    elif (s['teza'] <= 105):
        return 'moški 105 kg'
    elif (s['teza'] <= 120):
        return 'moški 120 kg'
    else:
        return 'moški +120 kg'
    
def kategorija_z(s):
    if (s['teza'] <= 47):
        return 'ženske 47 kg'
    elif (s['teza'] <= 52):
        return 'ženske 52 kg'
    elif (s['teza'] <= 57):
        return 'ženske 57 kg'
    elif (s['teza'] <= 63):
        return 'ženske 63 kg'
    elif (s['teza'] <= 72):
        return 'ženske 72 kg'
    elif (s['teza'] <= 84):
        return 'ženske 84 kg'
    else:
        return 'ženske +84 kg'

MM['kategorija'] = MM.apply(kategorija_m, axis=1)
WM['kategorija'] = WM.apply(kategorija_z, axis=1)
tekmovalci = pd.concat([MM, WM])
tekmovalci
# Out:
#               uvrstitev                     ime razred  letnica_rojstva  \
# ID_tekmovalca
# 1016033               1          Śledż Sławomir     M1             1976
# 1016034               2             Brinker Ron     M1             1975
# 1016035               1      Alcantara Anderson     M1             1976
# 1016036               2           Noppers Lewis     M1             1970
# 1016037               3  Rheaume Jean-Sebastien     M1             1974
# 1016038               4            Murray Greig     M1             1971
# 1016039               5        Cagliola Michael     M1             1970
# 1016040               6          Bernard Mikael     M1             1970
# 1016041               7    Hamilton-Smith Roger     M1             1975
# 1016042               8            McLaren Paul     M1             1974
# ...                 ...                     ...    ...              ...
# 1044506               1    Marksteiner Cathleen     M3             1958
# 1044507               1           Takáčová Hana     M3             1954
# 1044508               2            Hallen Susan     M3             1957
# 1044509               1         Kumpuniemi Eila     M4             1942
# 1044510               1             Elwyn Susan     M4             1947
# 1044511               2              Burns Bebe     M4             1942
# 1044512               1          Malicot Maryse     M4             1946
# 1044513               2        Uvachan Nadezhda     M4             1944
# 1044514               1          Fomina Tatyana     M4             1946
# 1044515               1              Moore Gail     M4             1947
#
#                        drzava    teza  pocep  potisk_s_prsi  mrtvi_dvig  \
# ID_tekmovalca
# 1016033                Poland   58.57    185            140         200
# 1016034                   USA   58.35    152            100         177
# 1016035                Brazil   65.67    195            135         270
# 1016036                Canada   65.53    195            135         255
# 1016037                Canada   65.70    205            130         235
# 1016038         Great Britain   65.10    165            127         232
# 1016039                   USA   65.70    177            132         215
# 1016040                France   65.02    167            145         210
# 1016041         Great Britain   65.18    180            115         225
# 1016042               Ireland   65.84    162             87         237
# ...                       ...     ...    ...            ...         ...
# 1044506                   USA   63.30     95             75         140
# 1044507        Czech Republic   85.50    190            132         160
# 1044508                   USA  105.50    170            105         155
# 1044509               Finland   46.48     90             45         100
# 1044510                   USA   47.30    100             45         130
# 1044511                   USA   50.60     77             42          90
# 1044512                France   52.50     90             45          95
# 1044513                Russia   55.20     80             45          85
# 1044514                Russia   60.35    115             50         130
# 1044515                   USA   71.40    130             87         142
#
#                skupaj   tocke     kategorija
# ID_tekmovalca
# 1016033           525  457.85    moški 59 kg
# 1016034           430  376.33    moški 59 kg
# 1016035           600  473.46    moški 66 kg
# 1016036           585  462.06    moški 66 kg
# 1016037           570  449.25    moški 66 kg
# 1016038           525  416.94    moški 66 kg
# 1016039           525  413.78    moški 66 kg
# 1016040           522  415.39    moški 66 kg
# 1016041           520  412.55    moški 66 kg
# 1016042           487  383.55    moški 66 kg
# ...               ...     ...            ...
# 1044506           310  331.73   ženske 72 kg
# 1044507           483  427.00  ženske +84 kg
# 1044508           430  352.94  ženske +84 kg
# 1044509           235  319.26   ženske 47 kg
# 1044510           275  368.15   ženske 52 kg
# 1044511           210  267.34   ženske 52 kg
# 1044512           230  284.61   ženske 57 kg
# 1044513           210  249.89   ženske 57 kg
# 1044514           295  327.97   ženske 63 kg
# 1044515           360  353.35   ženske 72 kg
#
# [435 rows x 12 columns]

# %%
tekmovalci.iloc[1]
# Out:
# uvrstitev                    2
# ime                Brinker Ron
# razred                      M1
# letnica_rojstva           1975
# drzava                     USA
# teza                     58.35
# pocep                      152
# potisk_s_prsi              100
# mrtvi_dvig                 177
# skupaj                     430
# tocke                   376.33
# kategorija         moški 59 kg
# Name: 1016034, dtype: object

# %%
tekmovalci.teza >= 80
tekmovalci[tekmovalci.teza >= 80]
# Out:
#               uvrstitev                   ime razred  letnica_rojstva  \
# ID_tekmovalca
# 1016050               1       Sipiläinen Pasi     M1             1978
# 1016051               2         Rowe Benjamin     M1             1976
# 1016052               3              Mills PK     M1             1975
# 1016053               4  Turakhanov Davranbek     M1             1974
# 1016054               5       Sanaki Munetaka     M1             1978
# 1016055               6         Mohamed Marie     M1             1977
# 1016056               7        Daniels Marlon     M1             1975
# 1016059               1        Garcia Gabriel     M1             1975
# 1016060               2       Summers Brandon     M1             1977
# 1016061               3          Butt Jeffrey     M1             1970
# ...                 ...                   ...    ...              ...
# 1044635               2        Puhakka Tapani     M4             1944
# 1044636               1        Sandelin Raimo     M4             1940
# 1044476               1   Burroughs Catherine     M1             1976
# 1044477               1        Nikzad Fatemeh     M1             1978
# 1044495               1        Styrlund Laura     M2             1964
# 1044497               3       Steidle Susanne     M2             1964
# 1044498               4        Nakari Susanne     M2             1968
# 1044499               1   Blasbery Jacqueline     M2             1963
# 1044507               1         Takáčová Hana     M3             1954
# 1044508               2          Hallen Susan     M3             1957
#
#                        drzava    teza  pocep  potisk_s_prsi  mrtvi_dvig  \
# ID_tekmovalca
# 1016050               Finland   82.75    227            165         290
# 1016051                   USA   82.32    250            160         255
# 1016052                Canada   82.65    225            147         282
# 1016053            Kazakhstan   80.70    232            142         257
# 1016054                 Japan   81.96    220            147         250
# 1016055                 Egypt   80.65    205            150         257
# 1016056          South Africa   81.14    230            160         215
# 1016059                Mexico   91.09    270            172         287
# 1016060                Canada   92.20    267            192         270
# 1016061                Canada   92.47    257            165         272
# ...                       ...     ...    ...            ...         ...
# 1044635               Finland   93.10     70            105         140
# 1044636               Finland  118.35     85             80         120
# 1044476         Great Britain   82.25    165             87         167
# 1044477                  Iran   84.85    125             70         145
# 1044495                   USA   82.60    165            127         180
# 1044497               Germany   80.70    140             92         170
# 1044498               Finland   81.10    120             75         115
# 1044499         Great Britain   88.05    152            120         180
# 1044507        Czech Republic   85.50    190            132         160
# 1044508                   USA  105.50    170            105         155
#
#                skupaj   tocke
# ID_tekmovalca
# 1016050           682  456.39
# 1016051           665  446.07
# 1016052           655  438.31
# 1016053           632  429.46
# 1016054           617  415.31
# 1016055           612  416.04
# 1016056           605  409.41
# 1016059           730  463.22
# 1016060           730  460.48
# 1016061           695  437.78
# ...               ...     ...
# 1044635           315  197.78
# 1044636           285  164.39
# 1044476           420  378.59
# 1044477           340  301.69
# 1044495           472  424.97
# 1044497           402  366.53
# 1044498           310  281.54
# 1044499           452  394.67
# 1044507           483  427.00
# 1044508           430  352.94
#
# [207 rows x 11 columns]
